# %%
# =============================================================
# Copyright © 2020 Intel Corporation
# 
# SPDX-License-Identifier: MIT
# =============================================================

# %% [markdown]
# # Intel® Neural Compressor Sample for TensorFlow*

# %% [markdown]
# ## Agenda
# - Train a convolutional neural network (CNN) model by using Keras
# - Quantize the Keras model by using Intel® Neural Compressor
# - Compare the quantized model with the original model

# %% [markdown]
# ## Setup
#
# Import python packages and verify that the correct versions are installed.
#
# Required packages:
# - TensorFlow 2.2 and later
# - Intel® Neural Compressor 1.2.1 and later
# - Matplotlib
#
# **Note**: This code sample supports both the current package name for Intel® Neural Compressor (**neural_compressor**) and the old names (**lpot**, **ilit**).
#
# **Please run this sample in the Intel TensorFlow & Quantization Jupyter Kernel environment.**

# %%
import tensorflow as tf
print("Tensorflow version {}".format(tf.__version__))
tf.compat.v1.enable_eager_execution()

try:
    import neural_compressor as inc
    print("neural_compressor version {}".format(inc.__version__))  
except:
    try:
        import lpot as inc
        print("LPOT version {}".format(inc.__version__)) 
    except:
        import ilit as inc
        print("iLiT version {}".format(inc.__version__))       

import matplotlib.pyplot as plt
import numpy as np
# Out:
# 2024-02-26 19:37:26.166289: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-26 19:37:26.168109: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-26 19:37:26.198816: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 19:37:26.198840: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 19:37:26.198864: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 19:37:26.204638: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-26 19:37:26.205139: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-26 19:37:27.015688: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-02-26 19:37:27.607657: I itex/core/wrapper/itex_cpu_wrapper.cc:42] Intel Extension for Tensorflow* AVX512 CPU backend is loaded.
# 2024-02-26 19:37:28.192475: I itex/core/wrapper/itex_gpu_wrapper.cc:35] Intel Extension for Tensorflow* GPU backend is loaded.
# 2024-02-26 19:37:28.231457: W itex/core/ops/op_init.cc:58] Op: _QuantizedMaxPool3D is already registered in Tensorflow
# 2024-02-26 19:37:28.290940: I itex/core/devices/gpu/itex_gpu_runtime.cc:129] Selected platform: Intel(R) Level-Zero
# 2024-02-26 19:37:28.291309: I itex/core/devices/gpu/itex_gpu_runtime.cc:154] number of sub-devices is zero, expose root device.
# Tensorflow version 2.14.0
# neural_compressor version 2.4.1

# %% [markdown]
# ### Environment Setting

# %% [markdown]
# For Intel Optimized TensorFlow 2.5.0 and later, you must set the **TF_ENABLE_MKL_NATIVE_FORMAT=0** environment variable before running Intel® Neural Compressor to quantize FP32 model or deploying the quantized model.

# %%
# %env TF_ENABLE_MKL_NATIVE_FORMAT=0
# Out:
# env: TF_ENABLE_MKL_NATIVE_FORMAT=0

# %% [markdown]
# ## Train a CNN Model Based on Keras
#
# We prepared the `alexnet.py` script with the functions for training a CNN model.
#
# ### Dataset
# Use the [MNIST](http://yann.lecun.com/exdb/mnist/) dataset of handwritten digits.
# Load the dataset.

# %%
import alexnet
 
data = alexnet.read_data()
x_train, y_train, label_train, x_test, y_test, label_test = data
print('train', x_train.shape, y_train.shape, label_train.shape)
print('test', x_test.shape, y_test.shape, label_test.shape)
# Out:
# Loading data ...
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step
# Done
# train (60000, 28, 28, 1) (60000, 10) (60000,)
# test (10000, 28, 28, 1) (10000, 10) (10000,)

# %% [markdown]
# ### Build Model
#
# Build a CNN model like Alexnet by using Keras API based on TensorFlow.
# Use the Keras `summary()` method to print the model structure.

# %%
classes = 10
width = 28
channels = 1

model = alexnet.create_model(width ,channels ,classes)

model.summary()
# Out:
# 2024-02-26 19:37:31.877982: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:37:31.878042: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# WARNING:absl:`lr` is deprecated in Keras optimizer, please use `learning_rate` or use the legacy optimizer, e.g.,tf.keras.optimizers.legacy.Adam.
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 28, 28, 96)        11712
#
#  activation (Activation)     (None, 28, 28, 96)        0
#
#  max_pooling2d (MaxPooling2  (None, 14, 14, 96)        0
#  D)
#
#  conv2d_1 (Conv2D)           (None, 14, 14, 256)       614656
#
#  activation_1 (Activation)   (None, 14, 14, 256)       0
#
#  max_pooling2d_1 (MaxPoolin  (None, 7, 7, 256)         0
#  g2D)
#
#  conv2d_2 (Conv2D)           (None, 7, 7, 384)         885120
#
#  activation_2 (Activation)   (None, 7, 7, 384)         0
#
#  conv2d_3 (Conv2D)           (None, 7, 7, 384)         1327488
#
#  activation_3 (Activation)   (None, 7, 7, 384)         0
#
#  conv2d_4 (Conv2D)           (None, 7, 7, 256)         884992
#
#  activation_4 (Activation)   (None, 7, 7, 256)         0
#
#  conv2d_5 (Conv2D)           (None, 1, 1, 256)         3211520
#
#  activation_5 (Activation)   (None, 1, 1, 256)         0
#
#  flatten (Flatten)           (None, 256)               0
#
#  dense (Dense)               (None, 10)                2570
#
#  activation_6 (Activation)   (None, 10)                0
#
# =================================================================
# Total params: 6938058 (26.47 MB)
# Trainable params: 6938058 (26.47 MB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# ### Train the Model with the Dataset
#
# Set the **epochs** parameter to **3**.

# %%
epochs = 3

alexnet.train_mod(model, data, epochs)
# Out:
# Epoch 1/3
# 2024-02-26 19:37:59.030907: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type CPU is enabled.
# 100/100 [==============================] - 192s 928ms/step - loss: 0.5263 - accuracy: 0.8265 - val_loss: 0.0489 - val_accuracy: 0.9828
# Epoch 2/3
# 100/100 [==============================] - 95s 949ms/step - loss: 0.0566 - accuracy: 0.9835 - val_loss: 0.0417 - val_accuracy: 0.9871
# Epoch 3/3
# 100/100 [==============================] - 96s 958ms/step - loss: 0.0378 - accuracy: 0.9881 - val_loss: 0.0328 - val_accuracy: 0.9884
# Test score: 0.0349867157638073
# Test accuracy: 0.9884000420570374

# %% [markdown]
# ### Freeze and Save Model to Single PB
#
# Set the input node name to **x**.

# %%
from tensorflow.python.framework.convert_to_constants import convert_variables_to_constants_v2

def save_frezon_pb(model, mod_path):
    # Convert Keras model to ConcreteFunction
    full_model = tf.function(lambda x: model(x))
    concrete_function = full_model.get_concrete_function(
        x=tf.TensorSpec(model.inputs[0].shape, model.inputs[0].dtype))

    # Get frozen ConcreteFunction
    frozen_model = convert_variables_to_constants_v2(concrete_function)

    # Generate frozen pb
    tf.io.write_graph(graph_or_graph_def=frozen_model.graph,
                      logdir=".",
                      name=mod_path,
                      as_text=False)
fp32_frezon_pb_file = "fp32_frozen.pb"
save_frezon_pb(model, fp32_frezon_pb_file)
# Out:
# 2024-02-26 19:44:28.800176: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-26 19:44:28.800282: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-26 19:44:28.800888: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:44:28.800920: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)

# %%
# !ls -la fp32_frezon.pb
# Out:
# -rw-r--r--. 1 1001060000 root 27760585 Feb 26 19:44 fp32_frezon.pb

# %% [markdown]
# ## Quantize FP32 Model by Using Intel® Neural Compressor
#
# Intel® Neural Compressor can quantize the model with a validation dataset for tuning.
# As a result, it returns a frozen quantized INT8 model.
#
# We prepare a python script `inc_quantize_model.py` to call Intel® Neural Compressor to finish the all quantization job.
# See the following code sample for explanations.
#
# ### Define Dataloader
#
# The class **Dataloader** provides an iter function to return the image and label as batch size.
# We uses the validation data of MNIST dataset.

# %%
import mnist_dataset
import math


class Dataloader(object):
  def __init__(self, batch_size):
    self.batch_size = batch_size


  def __iter__(self):
    x_train, y_train, label_train, x_test, y_test,label_test = mnist_dataset.read_data()
    batch_nums = math.ceil(len(x_test)/self.batch_size)

    for i in range(batch_nums-1):
        begin = i*self.batch_size
        end = (i+1)*self.batch_size
        yield x_test[begin: end], label_test[begin: end]

    begin = (batch_nums-1)*self.batch_size
    yield x_test[begin:], label_test[begin:]

# %% [markdown]
# ### Define Load FP32 Model
# Load the FP32 model that we saved in the previous step. See the `alexnet.load_pb(in_model)` function.

# %%
# !cat alexnet.py
# Out:
# import os
# import numpy as np
#
# import tensorflow as tf
# from tensorflow.python.keras import utils
#
# from tensorflow.keras.models import Sequential
# from tensorflow.keras.layers import Dense, Dropout, Flatten, Activation, Reshape
# from tensorflow.keras.layers import Convolution2D, MaxPooling2D
# from tensorflow.keras.layers import BatchNormalization
# from tensorflow.keras.optimizers import SGD, Adam
# from tensorflow import keras
#
# import mnist_dataset
#
#
# def save_mod(model, mod_path):
#     print('Save to {}'.format(mod_path))
#     tf.saved_model.save(model, mod_path)
#
#
# def load_mod(model_file):
#     model = tf.keras.models.load_model(model_file)
#     print('Load from {}'.format(model_file))
#     return model
#
# def save_frezon_pb(model, mod_path):
#     # Convert Keras model to ConcreteFunction
#     full_model = tf.function(lambda x: model(x))
#     concrete_function = full_model.get_concrete_function(
#         x=tf.TensorSpec(model.inputs[0].shape, model.inputs[0].dtype))
#
#     # Get frozen ConcreteFunction
#     frozen_model = convert_variables_to_constants_v2(concrete_function)
#
#     # Generate frozen pb
#     tf.io.write_graph(graph_or_graph_def=frozen_model.graph,
#                       logdir=".",
#                       name=mod_path,
#                       as_text=False)
#
#
# def load_pb(in_model):
#     detection_graph = tf.compat.v1.Graph()
#     with detection_graph.as_default():
#         od_graph_def = tf.compat.v1.GraphDef()
#         with tf.compat.v1.gfile.GFile(in_model, 'rb') as fid:
#             serialized_graph = fid.read()
#             od_graph_def.ParseFromString(serialized_graph)
#             tf.compat.v1.import_graph_def(od_graph_def, name='')
#
#     return detection_graph
#
# def read_data():
#     x_train, y_train, label_train, x_test, y_test, label_test = mnist_dataset.read_data()
#     return x_train, y_train, label_train, x_test, y_test, label_test
#
# def create_model(w, c, classes):
#     model = Sequential()
#     model.add(Convolution2D(96, 11, input_shape=(w, w, c), padding='same'))
#     model.add(Activation('relu'))
#     model.add(MaxPooling2D(pool_size=(2, 2)))
#
#     model.add(Convolution2D(256, 5, padding='same'))
#     model.add(Activation('relu'))
#     model.add(MaxPooling2D(pool_size=(2, 2)))
#
#     model.add(Convolution2D(384, 3, padding='same'))
#     model.add(Activation('relu'))
#
#     model.add(Convolution2D(384, 3, padding='same'))
#     model.add(Activation('relu'))
#
#     model.add(Convolution2D(256, 3, padding='same'))
#     model.add(Activation('relu'))
#
#     model.add(Convolution2D(256, 7))
#     model.add(Activation('relu'))
#
#     model.add(Flatten())
#     model.add(Dense(classes))
#     model.add(Activation('softmax'))
#
#     opt = Adam(lr=0.001)
#     model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])
#     return model
#
# def train_mod(model, data, epochs=3):
#     x_train, y_train, label_train, x_test, y_test, label_test = data
#     model.fit(x_train, y_train, epochs=epochs, batch_size=600, validation_data=(x_test, y_test), verbose=1)
#     score = model.evaluate(x_test, y_test, verbose=0)
#     print('Test score:', score[0])
#     print('Test accuracy:', score[1])
#
# def main():
#     data = read_data()
#
#     classes = 10
#     w = 28
#     c = 1
#     model = create_model(w ,c, classes)
#     model.summary()
#
#     epochs = 3
#     train_mod(model, data, epochs)
#     save_mod(model, "alexnet_mnist_fp32_mod")
#
# if __name__ == "__main__":
#     main()

# %% [markdown]
# ### Define Yaml File
#
# We created `alexnet.yaml` to save the necessary parameters for Intel® Neural Compressor.
# In this case, we only need to change the input/output according to the FP32 model.
#
# The input node name is **x**.
#
# The output name is **Identity**.

# %%
# !cat alexnet.yaml
# Out:
# version: 1.0
#
# model:
#   name: hello_world
#   framework: tensorflow                          # possible values are tensorflow, mxnet and pytorch
#   inputs: x
#   outputs: Identity
#
# evaluation:
#   accuracy:
#     metric:
#       topk: 1
#
# tuning:
#   accuracy_criterion:
#     relative: 0.01                              # the tuning target of accuracy loss percentage: 1%
#   exit_policy:
#     timeout: 0                                   # tuning timeout (seconds)
#   random_seed: 100                               # random seed

# %% [markdown]
# ### Define Tuning Function
# We follow the template to create the tuning function. The function will return a frozen quantized model (INT8 model).

# %%
def auto_tune(input_graph_path, yaml_config, batch_size):    
    fp32_graph = alexnet.load_pb(input_graph_path)
    quan = inc.Quantization(yaml_config)
    dataloader = Dataloader(batch_size)
    assert(dataloader)
    q_model = quan(
                        fp32_graph,
                        q_dataloader=dataloader,
                        eval_func=None,
                        eval_dataloader=dataloader)
    return q_model


def save_int8_frezon_pb(q_model, path):
    from tensorflow.python.platform import gfile
    f = gfile.GFile(path, 'wb')
    f.write(q_model.as_graph_def().SerializeToString())
    print("Save to {}".format(path))
    
yaml_file = "alexnet.yaml"
batch_size = 200
int8_pb_file = "alexnet_int8_model.pb"

# %% [markdown]
# ### Call Function to Quantize the Model
#
# Show the code in `inc_quantize_model.py`.

# %%
# !cat inc_quantize_model.py
# Out:
# import sys
#
# try:
#     import neural_compressor as inc
#     print("neural_compressor version {}".format(inc.__version__))
# except:
#     try:
#         import lpot as inc
#         print("LPOT version {}".format(inc.__version__))
#     except:
#         import ilit as inc
#         print("iLiT version {}".format(inc.__version__))
#
# if inc.__version__ == '1.2':
#     print("This script doesn't support LPOT 1.2, please install LPOT 1.1, 1.2.1 or newer")
#     sys.exit(1)
#
# import alexnet
# import math
# import mnist_dataset
#
#
# def save_int8_frezon_pb(q_model, path):
#     from tensorflow.python.platform import gfile
#     f = gfile.GFile(path, 'wb')
#     f.write(q_model.as_graph_def().SerializeToString())
#     print("Save to {}".format(path))
#
#
# class Dataloader(object):
#     def __init__(self, batch_size):
#         self.batch_size = batch_size
#
#     def __iter__(self):
#         x_train, y_train, label_train, x_test, y_test, label_test = mnist_dataset.read_data()
#         batch_nums = math.ceil(len(x_test) / self.batch_size)
#
#         for i in range(batch_nums - 1):
#             begin = i * self.batch_size
#             end = (i + 1) * self.batch_size
#             yield x_test[begin: end], label_test[begin: end]
#
#         begin = (batch_nums - 1) * self.batch_size
#         yield x_test[begin:], label_test[begin:]
#
#
# def auto_tune(input_graph_path, yaml_config, batch_size):
#     fp32_graph = alexnet.load_pb(input_graph_path)
#     quan = inc.Quantization(yaml_config)
#     dataloader = Dataloader(batch_size)
#
#     q_model = quan(
#         fp32_graph,
#         q_dataloader=dataloader,
#         eval_func=None,
#         eval_dataloader=dataloader)
#     return q_model
#
#
# yaml_file = "alexnet.yaml"
# batch_size = 200
# fp32_frezon_pb_file = "fp32_frezon.pb"
# int8_pb_file = "alexnet_int8_model.pb"
#
# q_model = auto_tune(fp32_frezon_pb_file, yaml_file, batch_size)
# save_int8_frezon_pb(q_model, int8_pb_file)

# %% [markdown]
# We will execute `inc_quantize_model.py` to show the whole process of quantizing a model.

# %%
# !python inc_quantize_model.py
# Out:
# neural_compressor version 2.4.1
# 2024-02-26 19:46:58.801848: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-26 19:46:58.805035: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-26 19:46:58.834728: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 19:46:58.834758: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 19:46:58.834780: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 19:46:58.840321: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-26 19:46:58.840515: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-26 19:46:59.562176: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-02-26 19:46:59.996525: I itex/core/wrapper/itex_cpu_wrapper.cc:42] Intel Extension for Tensorflow* AVX512 CPU backend is loaded.
# 2024-02-26 19:47:00.554871: I itex/core/wrapper/itex_gpu_wrapper.cc:35] Intel Extension for Tensorflow* GPU backend is loaded.
# 2024-02-26 19:47:00.592023: W itex/core/ops/op_init.cc:58] Op: _QuantizedMaxPool3D is already registered in Tensorflow
# 2024-02-26 19:47:00.641818: I itex/core/devices/gpu/itex_gpu_runtime.cc:129] Selected platform: Intel(R) Level-Zero
# 2024-02-26 19:47:00.642180: I itex/core/devices/gpu/itex_gpu_runtime.cc:154] number of sub-devices is zero, expose root device.
# tensorflow 2.14.0
# Loading data ...
# Done
# 2024-02-26 19:47:01 [WARNING] Output tensor names should not be empty.
# 2024-02-26 19:47:01 [WARNING] Input tensor names is empty.
# 2024-02-26 19:47:01 [INFO] Start auto tuning.
# 2024-02-26 19:47:01 [INFO] Create evaluation function according to evaluation dataloader and metric                and Execute the tuning process.
# 2024-02-26 19:47:01 [INFO] Adaptor has 5 recipes.
# 2024-02-26 19:47:01 [INFO] 0 recipes specified by user.
# 2024-02-26 19:47:01 [INFO] 3 recipes require future tuning.
# 2024-02-26 19:47:01 [INFO] *** Initialize auto tuning
# 2024-02-26 19:47:01 [INFO] {
# 2024-02-26 19:47:01 [INFO]     'PostTrainingQuantConfig': {
# 2024-02-26 19:47:01 [INFO]         'AccuracyCriterion': {
# 2024-02-26 19:47:01 [INFO]             'criterion': 'relative',
# 2024-02-26 19:47:01 [INFO]             'higher_is_better': True,
# 2024-02-26 19:47:01 [INFO]             'tolerable_loss': 0.01,
# 2024-02-26 19:47:01 [INFO]             'absolute': None,
# 2024-02-26 19:47:01 [INFO]             'keys': <bound method AccuracyCriterion.keys of <neural_compressor.config.AccuracyCriterion object at 0x7fa6ff140520>>,
# 2024-02-26 19:47:01 [INFO]             'relative': 0.01
# 2024-02-26 19:47:01 [INFO]         },
# 2024-02-26 19:47:01 [INFO]         'approach': 'post_training_static_quant',
# 2024-02-26 19:47:01 [INFO]         'backend': 'default',
# 2024-02-26 19:47:01 [INFO]         'calibration_sampling_size': [
# 2024-02-26 19:47:01 [INFO]             100
# 2024-02-26 19:47:01 [INFO]         ],
# 2024-02-26 19:47:01 [INFO]         'device': 'cpu',
# 2024-02-26 19:47:01 [INFO]         'diagnosis': False,
# 2024-02-26 19:47:01 [INFO]         'domain': 'auto',
# 2024-02-26 19:47:01 [INFO]         'example_inputs': 'Not printed here due to large size tensors...',
# 2024-02-26 19:47:01 [INFO]         'excluded_precisions': [
# 2024-02-26 19:47:01 [INFO]         ],
# 2024-02-26 19:47:01 [INFO]         'framework': 'tensorflow',
# 2024-02-26 19:47:01 [INFO]         'inputs': [
# 2024-02-26 19:47:01 [INFO]         ],
# 2024-02-26 19:47:01 [INFO]         'model_name': '',
# 2024-02-26 19:47:01 [INFO]         'ni_workload_name': 'quantization',
# 2024-02-26 19:47:01 [INFO]         'op_name_dict': None,
# 2024-02-26 19:47:01 [INFO]         'op_type_dict': None,
# 2024-02-26 19:47:01 [INFO]         'outputs': [
# 2024-02-26 19:47:01 [INFO]         ],
# 2024-02-26 19:47:01 [INFO]         'quant_format': 'default',
# 2024-02-26 19:47:01 [INFO]         'quant_level': 'auto',
# 2024-02-26 19:47:01 [INFO]         'recipes': {
# 2024-02-26 19:47:01 [INFO]             'smooth_quant': False,
# 2024-02-26 19:47:01 [INFO]             'smooth_quant_args': {
# 2024-02-26 19:47:01 [INFO]             },
# 2024-02-26 19:47:01 [INFO]             'layer_wise_quant': False,
# 2024-02-26 19:47:01 [INFO]             'layer_wise_quant_args': {
# 2024-02-26 19:47:01 [INFO]             },
# 2024-02-26 19:47:01 [INFO]             'fast_bias_correction': False,
# 2024-02-26 19:47:01 [INFO]             'weight_correction': False,
# 2024-02-26 19:47:01 [INFO]             'gemm_to_matmul': True,
# 2024-02-26 19:47:01 [INFO]             'graph_optimization_level': None,
# 2024-02-26 19:47:01 [INFO]             'first_conv_or_matmul_quantization': True,
# 2024-02-26 19:47:01 [INFO]             'last_conv_or_matmul_quantization': True,
# 2024-02-26 19:47:01 [INFO]             'pre_post_process_quantization': True,
# 2024-02-26 19:47:01 [INFO]             'add_qdq_pair_to_weight': False,
# 2024-02-26 19:47:01 [INFO]             'optypes_to_exclude_output_quant': [
# 2024-02-26 19:47:01 [INFO]             ],
# 2024-02-26 19:47:01 [INFO]             'dedicated_qdq_pair': False,
# 2024-02-26 19:47:01 [INFO]             'rtn_args': {
# 2024-02-26 19:47:01 [INFO]             },
# 2024-02-26 19:47:01 [INFO]             'awq_args': {
# 2024-02-26 19:47:01 [INFO]             },
# 2024-02-26 19:47:01 [INFO]             'gptq_args': {
# 2024-02-26 19:47:01 [INFO]             },
# 2024-02-26 19:47:01 [INFO]             'teq_args': {
# 2024-02-26 19:47:01 [INFO]             },
# 2024-02-26 19:47:01 [INFO]             'scale_propagation_max_pooling': True,
# 2024-02-26 19:47:01 [INFO]             'scale_propagation_concat': True
# 2024-02-26 19:47:01 [INFO]         },
# 2024-02-26 19:47:01 [INFO]         'reduce_range': None,
# 2024-02-26 19:47:01 [INFO]         'TuningCriterion': {
# 2024-02-26 19:47:01 [INFO]             'max_trials': 100,
# 2024-02-26 19:47:01 [INFO]             'objective': [
# 2024-02-26 19:47:01 [INFO]                 'performance'
# 2024-02-26 19:47:01 [INFO]             ],
# 2024-02-26 19:47:01 [INFO]             'strategy': 'basic',
# 2024-02-26 19:47:01 [INFO]             'strategy_kwargs': None,
# 2024-02-26 19:47:01 [INFO]             'timeout': 0
# 2024-02-26 19:47:01 [INFO]         },
# 2024-02-26 19:47:01 [INFO]         'use_bf16': True
# 2024-02-26 19:47:01 [INFO]     }
# 2024-02-26 19:47:01 [INFO] }
# 2024-02-26 19:47:01 [WARNING] [Strategy] Please install `mpi4py` correctly if using distributed tuning; otherwise, ignore this warning.
# 2024-02-26 19:47:01.292143: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:01.292212: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:01 [WARNING] Found possible input node names: ['x'], output node names: ['Identity'].
# 2024-02-26 19:47:01 [INFO] ConvertLayoutOptimizer elapsed time: 0.07 ms
# 2024-02-26 19:47:01 [INFO] Pass ConvertPlaceholderToConst elapsed time: 0.43 ms
# 2024-02-26 19:47:01 [INFO] Pass SwitchOptimizer elapsed time: 0.47 ms
# 2024-02-26 19:47:01.409153: I tensorflow/core/grappler/devices.cc:66] Number of eligible GPUs (core count >= 8, compute capability >= 0.0): 0
# 2024-02-26 19:47:01.409303: I tensorflow/core/grappler/clusters/single_machine.cc:361] Starting new session
# 2024-02-26 19:47:01.410167: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:01.410204: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:01 [INFO] Pass GrapplerOptimizer elapsed time: 166.44 ms
# WARNING:tensorflow:From /opt/app-root/lib/python3.9/site-packages/neural_compressor/adaptor/tf_utils/util.py:399: extract_sub_graph (from tensorflow.python.framework.graph_util_impl) is deprecated and will be removed in a future version.
# Instructions for updating:
# This API was designed for TensorFlow v1. See https://www.tensorflow.org/guide/migrate for instructions on how to migrate your code to TensorFlow v2.
# 2024-02-26 19:47:01 [INFO] Pass StripUnusedNodesOptimizer elapsed time: 1.54 ms
# 2024-02-26 19:47:01 [INFO] Pass RemoveTrainingNodesOptimizer elapsed time: 0.36 ms
# 2024-02-26 19:47:01 [INFO] Pass SplitSharedInputOptimizer elapsed time: 0.19 ms
# 2024-02-26 19:47:01 [INFO] Pass GraphFoldConstantOptimizer elapsed time: 0.22 ms
# 2024-02-26 19:47:01 [INFO] Pass FuseDecomposedBNOptimizer elapsed time: 0.55 ms
# 2024-02-26 19:47:01 [INFO] Pass FuseColumnWiseMulOptimizer elapsed time: 0.41 ms
# 2024-02-26 19:47:01 [INFO] Pass StripUnusedNodesOptimizer elapsed time: 0.94 ms
# 2024-02-26 19:47:01 [INFO] Pass GraphCseOptimizer elapsed time: 0.35 ms
# 2024-02-26 19:47:01 [INFO] Pass FoldBatchNormNodesOptimizer elapsed time: 0.34 ms
# 2024-02-26 19:47:01 [INFO] Pass RenameBatchNormOptimizer elapsed time: 0.32 ms
# 2024-02-26 19:47:01 [INFO] Pass ConvertLeakyReluOptimizer elapsed time: 0.32 ms
# 2024-02-26 19:47:01 [INFO] Pass ConvertAddToBiasAddOptimizer elapsed time: 0.36 ms
# 2024-02-26 19:47:01 [INFO] Pass FuseTransposeReshapeOptimizer elapsed time: 0.37 ms
# 2024-02-26 19:47:01 [INFO] Pass FuseConvWithMathOptimizer elapsed time: 0.37 ms
# 2024-02-26 19:47:01 [INFO] Pass ExpandDimsOptimizer elapsed time: 0.34 ms
# 2024-02-26 19:47:01 [INFO] Pass FetchWeightFromReshapeOptimizer elapsed time: 0.35 ms
# 2024-02-26 19:47:01 [INFO] Pass MoveSqueezeAfterReluOptimizer elapsed time: 0.34 ms
# 2024-02-26 19:47:01 [WARNING] Found possible input node names: ['x'], output node names: ['Identity'].
# 2024-02-26 19:47:01 [INFO] Pass InjectDummyBiasAddOptimizer elapsed time: 0.51 ms
# 2024-02-26 19:47:01 [WARNING] All replaced equivalent node types are {}
# 2024-02-26 19:47:01 [INFO] Pass StripEquivalentNodesOptimizer elapsed time: 1.35 ms
# 2024-02-26 19:47:01.623653: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:01.623725: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:01 [INFO] Pass Pre Optimization elapsed time: 292.07 ms
# 2024-02-26 19:47:01.675981: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:01.676036: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:01 [INFO] Get FP32 model baseline.
# 2024-02-26 19:47:01 [INFO] Start to evaluate the TensorFlow model.
# 2024-02-26 19:47:01.771007: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:382] MLIR V1 optimization pass is not enabled
# 2024-02-26 19:47:01.781413: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type CPU is enabled.
# 2024-02-26 19:47:03.261615: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:03.261684: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:05.358250: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:05.358346: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:06.163328: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:06.163405: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:06.666511: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:06.666571: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:07.459188: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:07.459267: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:07.961586: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:07.961678: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:08.561055: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:08.561137: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:08.960791: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:08.960886: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:09.462933: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:09.463010: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:10.061100: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:10.061176: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:10.562985: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:10.563068: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:11.062969: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:11.063050: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:11.958862: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:11.958945: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:12.362320: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:12.362399: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:13.158453: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:13.158728: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:13.659282: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:13.659364: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:13.966750: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:13.966829: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:14.560636: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:14.560718: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:15.060236: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:15.060326: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:15.462118: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:15.462199: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:15.962536: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:15.962632: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:16.558900: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:16.558983: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:17.059899: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:17.059982: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:17.558685: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:17.558867: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:17.963217: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:17.963296: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:18.464869: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:18.464930: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:18.963068: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:18.963161: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:19.462534: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:19.462632: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:19.962710: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:19.962788: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:20.463855: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:20.463935: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:21.060814: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:21.060899: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:21.663094: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:21.663179: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:22.066298: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:22.066391: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:22.760496: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:22.760581: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:23.263506: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:23.263588: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:23.858112: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:23.858190: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:24.462187: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:24.462261: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:24.963034: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:24.963109: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:25.464465: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:25.464544: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:25.967289: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:25.967379: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:26.661185: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:26.661272: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:27.166312: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:27.166397: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:27.662865: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:27.662962: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:28.161612: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:28.161693: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:28.661874: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:28.661955: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:29.263157: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:29.263240: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:29.665167: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:29.665261: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:30.160261: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:30.160348: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:30.858094: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:30.858193: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:31.359070: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:31.359150: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:31 [INFO] Model inference elapsed time: 29759.82 ms
# 2024-02-26 19:47:31 [INFO] Save tuning history to /opt/app-root/src/oneAPI-samples/Intel_Optimized_TensorFlow_and_INC_Quantization_Tool_E2E_Sample/nc_workspace/2024-02-26_19-46-56/./history.snapshot.
# 2024-02-26 19:47:31 [INFO] FP32 baseline is: [Accuracy: 0.9884, Duration (seconds): 29.7602]
# 2024-02-26 19:47:31 [INFO] Quantize the model with default config.
# 2024-02-26 19:47:31 [WARNING] Reset `calibration.dataloader.batch_size` field to 100 to make sure the sampling_size is divisible exactly by batch size
# 2024-02-26 19:47:31.504364: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-26 19:47:31.550405: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:31.550477: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:31 [WARNING] Found possible input node names: ['x'], output node names: ['Identity'].
# 2024-02-26 19:47:31.641259: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:31.641332: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:31 [WARNING] Found possible input node names: ['x'], output node names: ['Identity'].
# 2024-02-26 19:47:31 [WARNING] Found possible input node names: ['x'], output node names: ['Identity'].
# 2024-02-26 19:47:31 [INFO] Pass Quantization elapsed time: 52.51 ms
# 2024-02-26 19:47:31.886186: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:31.886253: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:35 [WARNING] Found possible input node names: ['x'], output node names: ['Identity'].
# 2024-02-26 19:47:35 [WARNING] Found possible input node names: ['x'], output node names: ['Identity'].
# 2024-02-26 19:47:35 [WARNING] Found possible input node names: ['x'], output node names: ['sequential/conv2d/Conv2D_eightbit_reshape_x', 'sequential/dense/MatMul_eightbit_reshape_sequential/flatten/Reshape', 'Identity'].
# 2024-02-26 19:47:35 [INFO] Pass StripUnusedNodesOptimizer elapsed time: 1.94 ms
# 2024-02-26 19:47:35 [INFO] Pass RemoveTrainingNodesOptimizer elapsed time: 0.82 ms
# 2024-02-26 19:47:35 [INFO] Pass FoldBatchNormNodesOptimizer elapsed time: 0.62 ms
# 2024-02-26 19:47:35 [INFO] Pass MetaOpOptimizer elapsed time: 0.37 ms
# 2024-02-26 19:47:35 [WARNING] All replaced equivalent node types are {}
# 2024-02-26 19:47:35 [INFO] Pass StripEquivalentNodesOptimizer elapsed time: 2.02 ms
# 2024-02-26 19:47:35.171542: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:35.171613: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:35 [INFO] Pass PostCseOptimizer elapsed time: 102.98 ms
# 2024-02-26 19:47:35 [INFO] Pass PostHostConstConverter elapsed time: 0.7 ms
# 2024-02-26 19:47:35.304703: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:35.304766: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:35 [INFO] |******Mixed Precision Statistics******|
# 2024-02-26 19:47:35 [INFO] +-----------------+---------+----------+
# 2024-02-26 19:47:35 [INFO] |     Op Type     |  Total  |   INT8   |
# 2024-02-26 19:47:35 [INFO] +-----------------+---------+----------+
# 2024-02-26 19:47:35 [INFO] |      Conv2D     |    6    |    6     |
# 2024-02-26 19:47:35 [INFO] |     MaxPool     |    2    |    2     |
# 2024-02-26 19:47:35 [INFO] |      MatMul     |    1    |    1     |
# 2024-02-26 19:47:35 [INFO] |    QuantizeV2   |    2    |    2     |
# 2024-02-26 19:47:35 [INFO] |    Dequantize   |    1    |    1     |
# 2024-02-26 19:47:35 [INFO] +-----------------+---------+----------+
# 2024-02-26 19:47:35 [INFO] Pass quantize model elapsed time: 3817.62 ms
# 2024-02-26 19:47:35 [INFO] Start to evaluate the TensorFlow model.
# 2024-02-26 19:47:40.314064: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:40.314124: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:40.345746: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:40.345794: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:40.376735: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:40.376777: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:40.403459: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:40.403497: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:40.430696: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:40.430733: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:40.458568: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:40.458613: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:40.485516: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:40.485552: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:40.511546: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:40.511583: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# ...
# 2024-02-26 19:47:42.331803: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.358581: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.358626: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.388124: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.388164: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.417369: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.417409: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.446032: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.446070: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.474465: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.474503: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.501534: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.501571: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.528569: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.528615: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.555794: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.555833: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.585601: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.585639: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.612291: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.612329: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.640095: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.640137: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.666656: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.666695: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.694534: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.694573: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.720691: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.720728: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.748622: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.748659: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.776387: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.776427: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.804433: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.804472: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.834801: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.834840: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.862382: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.862421: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.890200: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.890237: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.916553: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.916590: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.942707: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.942745: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:42.972223: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:42.972263: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:43.004436: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:43.004475: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:43.030716: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:43.030755: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:43.062707: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:43.062745: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:43.091587: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:47:43.091630: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# 2024-02-26 19:47:43 [INFO] Model inference elapsed time: 7798.73 ms
# 2024-02-26 19:47:43 [INFO] Tune 1 result is: [Accuracy (int8|fp32): 0.9884|0.9884, Duration (seconds) (int8|fp32): 7.7990|29.7602], Best tune result is: [Accuracy: 0.9884, Duration (seconds): 7.7990]
# 2024-02-26 19:47:43 [INFO] |**********************Tune Result Statistics**********************|
# 2024-02-26 19:47:43 [INFO] +--------------------+----------+---------------+------------------+
# 2024-02-26 19:47:43 [INFO] |     Info Type      | Baseline | Tune 1 result | Best tune result |
# 2024-02-26 19:47:43 [INFO] +--------------------+----------+---------------+------------------+
# 2024-02-26 19:47:43 [INFO] |      Accuracy      | 0.9884   |    0.9884     |     0.9884       |
# 2024-02-26 19:47:43 [INFO] | Duration (seconds) | 29.7602  |    7.7990     |     7.7990       |
# 2024-02-26 19:47:43 [INFO] +--------------------+----------+---------------+------------------+
# 2024-02-26 19:47:43 [INFO] [Strategy] Found a model that meets the accuracy requirements.
# 2024-02-26 19:47:43 [INFO] Save tuning history to /opt/app-root/src/oneAPI-samples/Intel_Optimized_TensorFlow_and_INC_Quantization_Tool_E2E_Sample/nc_workspace/2024-02-26_19-46-56/./history.snapshot.
# 2024-02-26 19:47:43 [INFO] [Strategy] Found the model meets accuracy requirements, ending the tuning process.
# 2024-02-26 19:47:43 [INFO] Specified timeout or max trials is reached! Found a quantized model which meet accuracy goal. Exit.
# 2024-02-26 19:47:43 [INFO] Save deploy yaml to /opt/app-root/src/oneAPI-samples/Intel_Optimized_TensorFlow_and_INC_Quantization_Tool_E2E_Sample/nc_workspace/2024-02-26_19-46-56/deploy.yaml
# 2024-02-26 19:47:43 [INFO] Save quantized model to /opt/app-root/src/oneAPI-samples/Intel_Optimized_TensorFlow_and_INC_Quantization_Tool_E2E_Sample/alexnet_int8_model.pb.

# %% [markdown]
# The script creates the file `alexnet_int8_model.pb` that contains the quantized model.

# %% [markdown]
# ## Compare Quantized Model
#
# We prepare the script `profiling_inc.py` to test the performance of the PB model.
#
# If we run the code in the jupyter notebook, we will not get the correct performance data. So we run the script as a process.
#
# Let's take a look at `profiling_inc.py`.

# %%
# !cat profiling_inc.py
# Out:
# import tensorflow as tf
# print("Tensorflow version {}".format(tf.__version__))
#
# import numpy as np
# import time
# import argparse
# import os
# import json
#
#
# import mnist_dataset
# import alexnet
#
#
# def val_data():
#     x_train, y_train, label_train, x_test, y_test, label_test = mnist_dataset.read_data()
#     return x_test, y_test, label_test
#
#
# def calc_accuracy(predictions, labels):
#     predictions = np.argmax(predictions, axis=1)
#     same = 0
#     for i, x in enumerate(predictions):
#         if x == labels[i]:
#             same += 1
#     if len(predictions) == 0:
#         return 0
#     else:
#         return same / len(predictions)
#
#
# def get_concrete_function(graph_def, inputs, outputs, print_graph=False):
#     def imports_graph_def():
#         tf.compat.v1.import_graph_def(graph_def, name="")
#
#     wrap_function = tf.compat.v1.wrap_function(imports_graph_def, [])
#     graph = wrap_function.graph
#
#     return wrap_function.prune(
#         tf.nest.map_structure(graph.as_graph_element, inputs),
#         tf.nest.map_structure(graph.as_graph_element, outputs))
#
#
# def infer_perf_pb(pb_model_file, val_data, inputs=["x:0"], outputs=["Identity:0"]):
#     x_test, y_test, label_test = val_data
#     q_model = alexnet.load_pb(pb_model_file)
#     concrete_function = get_concrete_function(graph_def=q_model.as_graph_def(),
#                                               inputs=inputs,
#                                               outputs=outputs,
#                                               print_graph=True)
#
#     bt = time.time()
#     _frozen_graph_predictions = concrete_function(x=tf.constant(x_test))
#     et = time.time()
#
#     accuracy = calc_accuracy(_frozen_graph_predictions[0], label_test)
#     print('accuracy:', accuracy)
#     throughput = x_test.shape[0] / (et - bt)
#     print('max throughput(fps):', throughput)
#
#     # latency when BS=1
#     times = 1000
#     single_test = x_test[:1]
#
#     bt = 0
#     warmup = 20
#     for i in range(times):
#         if i == warmup:
#             bt = time.time()
#         _frozen_graph_predictions = concrete_function(x=tf.constant(single_test))
#     et = time.time()
#
#     latency = (et - bt) * 1000 / (times - warmup)
#     print('latency(ms):', latency)
#
#     return accuracy, throughput, latency
#
#
# def save_res(result):
#     accuracy, throughput, latency = result
#     res = {}
#     res['accuracy'] = accuracy
#     res['throughput'] = throughput
#     res['latency'] = latency
#
#     outfile = args.index + ".json"
#     with open(outfile, 'w') as f:
#         json.dump(res, f)
#         print("Save result to {}".format(outfile))
#
# parser = argparse.ArgumentParser()
# parser.add_argument('--index', type=str, help='file name of output', required=True)
#
# parser.add_argument('--input-graph', type=str, help='file name for graph', required=True)
#
# parser.add_argument('--num-intra-threads', type=str, help='number of threads for an operator', required=False,
#                     default="24" )
# parser.add_argument('--num-inter-threads', type=str, help='number of threads across operators', required=False,
#                     default="1")
# parser.add_argument('--omp-num-threads', type=str, help='number of threads to use', required=False,
#                     default="24")
#
# args = parser.parse_args()
# os.environ["KMP_BLOCKTIME"] = "1"
# os.environ["KMP_SETTINGS"] = "0"
# os.environ["OMP_NUM_THREADS"] = args.omp_num_threads
# os.environ["TF_NUM_INTEROP_THREADS"] = args.num_inter_threads
# os.environ["TF_NUM_INTRAOP_THREADS"] = args.num_intra_threads
#
# with tf.device("cpu"):
#     save_res(infer_perf_pb(args.input_graph, val_data()))

# %% [markdown]
# Execute `profiling_inc.py` with the FP32 model file:

# %%
# !python profiling_inc.py --input-graph=./fp32_frezon.pb --omp-num-threads=4 --num-inter-threads=1 --num-intra-threads=4 --index=32
# Out:
# 2024-02-26 19:44:36.605835: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-26 19:44:36.607579: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-26 19:44:36.636676: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 19:44:36.636707: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 19:44:36.636733: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 19:44:36.642552: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-26 19:44:36.642739: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-26 19:44:37.457362: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-02-26 19:44:38.003872: I itex/core/wrapper/itex_cpu_wrapper.cc:42] Intel Extension for Tensorflow* AVX512 CPU backend is loaded.
# 2024-02-26 19:44:38.556847: I itex/core/wrapper/itex_gpu_wrapper.cc:35] Intel Extension for Tensorflow* GPU backend is loaded.
# 2024-02-26 19:44:38.594818: W itex/core/ops/op_init.cc:58] Op: _QuantizedMaxPool3D is already registered in Tensorflow
# 2024-02-26 19:44:38.653662: I itex/core/devices/gpu/itex_gpu_runtime.cc:129] Selected platform: Intel(R) Level-Zero
# 2024-02-26 19:44:38.654029: I itex/core/devices/gpu/itex_gpu_runtime.cc:154] number of sub-devices is zero, expose root device.
# Tensorflow version 2.14.0
# 2024-02-26 19:44:39.098386: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:44:39.098429: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# Loading data ...
# Done
# 2024-02-26 19:44:39.802817: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type CPU is enabled.
# accuracy: 0.9884
# max throughput(fps): 1112.93269651875
# latency(ms): 6.165098900697669
# Save result to 32.json

# %% [markdown]
# Execute `profiling_inc.py` with the INT8 model file:

# %%
# !python profiling_inc.py --input-graph=./alexnet_int8_model.pb --omp-num-threads=4 --num-inter-threads=1 --num-intra-threads=4 --index=8
# Out:
# 2024-02-26 19:47:58.154384: I tensorflow/core/util/port.cc:111] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2024-02-26 19:47:58.156105: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-26 19:47:58.185505: E tensorflow/compiler/xla/stream_executor/cuda/cuda_dnn.cc:9342] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-26 19:47:58.185533: E tensorflow/compiler/xla/stream_executor/cuda/cuda_fft.cc:609] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-26 19:47:58.185556: E tensorflow/compiler/xla/stream_executor/cuda/cuda_blas.cc:1518] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-26 19:47:58.191363: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2024-02-26 19:47:58.191539: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-02-26 19:47:58.983006: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT
# 2024-02-26 19:47:59.514915: I itex/core/wrapper/itex_cpu_wrapper.cc:42] Intel Extension for Tensorflow* AVX512 CPU backend is loaded.
# 2024-02-26 19:48:00.060164: I itex/core/wrapper/itex_gpu_wrapper.cc:35] Intel Extension for Tensorflow* GPU backend is loaded.
# 2024-02-26 19:48:00.098378: W itex/core/ops/op_init.cc:58] Op: _QuantizedMaxPool3D is already registered in Tensorflow
# 2024-02-26 19:48:00.156546: I itex/core/devices/gpu/itex_gpu_runtime.cc:129] Selected platform: Intel(R) Level-Zero
# 2024-02-26 19:48:00.156920: I itex/core/devices/gpu/itex_gpu_runtime.cc:154] number of sub-devices is zero, expose root device.
# Tensorflow version 2.14.0
# 2024-02-26 19:48:00.613585: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform XPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-02-26 19:48:00.613629: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:XPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: XPU, pci bus id: <undefined>)
# Loading data ...
# Done
# 2024-02-26 19:48:01.036891: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:117] Plugin optimizer for device_type CPU is enabled.
# accuracy: 0.9884
# max throughput(fps): 3225.1643626559803
# latency(ms): 5.426162602950115
# Save result to 8.json

# %%
# !cat 32.json
# !echo " "
# !cat 8.json
# Out:
# {"accuracy": 0.9884, "throughput": 1112.93269651875, "latency": 6.165098900697669}
# cat: 8.json: No such file or directory

# %% [markdown]
# Execute the functions to load and show the performance data from the `32.json` and `8.json` files.

# %%
import json

def autolabel(ax, rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%0.2f' % float(height),
        ha='center', va='bottom')

def draw_bar(x, t, y, subplot, color, x_lab, y_lab, width=0.2):
    plt.subplot(subplot)
    plt.xticks(x, t)
    ax1 = plt.gca()
    ax1.set_xlabel(x_lab)
    ax1.set_ylabel(y_lab, color=color)
    rects1 = ax1.bar(x, y, color=color, width=width)
    ax1.tick_params(axis='y', labelcolor=color)
    autolabel(ax1, rects1)

def load_res(json_file):
    with open(json_file) as f:
        data = json.load(f)
        return data

res_32 = load_res('32.json')
res_8 = load_res('8.json')
   
accuracys = [res_32['accuracy'], res_8['accuracy']]
throughputs = [res_32['throughput'], res_8['throughput']]             
latencys = [res_32['latency'], res_8['latency']]

print('throughputs', throughputs)
print('latencys', latencys)
print('accuracys', accuracys)

accuracys_perc = [accu*100 for accu in accuracys]

t = ['FP32', 'INT8']
x = [0, 1]
plt.figure(figsize=(16,6))
draw_bar(x, t, throughputs, 131, 'tab:green', 'Throughput(fps)', '', width=0.2)
draw_bar(x, t,  latencys, 132, 'tab:blue', 'Latency(s)', '', width=0.2)
draw_bar(x, t,  accuracys_perc, 133, '#28a99d', 'Accuracys(%)', '', width=0.2)
plt.show()
# Out:
# throughputs [1112.93269651875, 3225.1643626559803]
# latencys [6.165098900697669, 5.426162602950115]
# accuracys [0.9884, 0.9884]

# %% [markdown]
# ### FP32 vs INT8
#
# Compare the performance data of the INT8 model with that of the FP32 model.

# %%
throughputs_times = [1, throughputs[1]/throughputs[0]]
latencys_times = [1, latencys[1]/latencys[0]]
accuracys_times = [0, accuracys_perc[1] - accuracys_perc[0]]

print('throughputs_times', throughputs_times)
print('latencys_times', latencys_times)
print('accuracys_times', accuracys_times)

plt.figure(figsize=(16,6))
draw_bar(x, t, throughputs_times, 131, 'tab:green', 'Throughput Comparison (big is better)', '', width=0.2)
draw_bar(x, t, latencys_times, 132, 'tab:blue', 'Latency Comparison (small is better)', '', width=0.2)
draw_bar(x, t, accuracys_times, 133, '#28a99d', 'Accuracys Loss(%)', '', width=0.2)
plt.show()
# Out:
# throughputs_times [1, 2.8978970361319103]
# latencys_times [1, 0.8801420204850351]
# accuracys_times [0, 0.0]

# %% [markdown]
# ## Conclusion

# %%
print("[CODE_SAMPLE_COMPLETED_SUCCESFULLY]")
# Out:
# [CODE_SAMPLE_COMPLETED_SUCCESFULLY]

# %% [markdown]
# In this code sample we have compared performance of the FP32 and INT8 models and demonstrated that the INT8 model is faster.
